# %% [markdown]
# # PHILOSOPHY NETWORKS:
# ## Extraction of Sentence-Co-Occurring Relationships among Concepts
# # Ludwig Wittgenstein's Tractatus Logico-Philosophicus

# %%
import nltk

# %%
import os
import re
import csv
import itertools
from nltk.tokenize import sent_tokenize, word_tokenize
# from nltk.tag.stanford import StanfordNERTagger
# java_path = "C:/Program Files/Java/jdk1.8.0_05/bin/java.exe"
# os.environ['JAVAHOME'] = java_path

# path2 = 'C:/Users/Pantelis/Desktop/NOTEBOOK/stanfordner'
# st =  StanfordNERTagger(path2+'/classifiers/english.all.3class.distsim.crf.ser.gz', 'stanford-ner.jar')

# st =  StanfordNERTagger('/Users/mosesboudourides/Dropbox/Python Projects/LiteratureNetworks/stanfordner/classifiers/english.all.3class.distsim.crf.ser.gz', '/Users/mosesboudourides/Dropbox/Python Projects/LiteratureNetworks/stanfordner/stanford-ner.jar')
# st = StanfordNERTagger('classifiers/english.all.3class.distsim.crf.ser.gz','/home/sergios-len/Downloads/stanford-ner-2015-12-09/stanford-ner.jar')


# f1 = open('Texts/Kierkegaard_Fear&Trembling.txt','r')

import codecs
f1 = codecs.open('Texts/Wittgenstein_TractatusLogico-Philosophicus.txt', "r", encoding="utf-8")
f1Temp = codecs.open("tempASCII", "w", encoding="ascii", errors="ignore")
f1Temp.write('Texts/Wittgenstein_TractatusLogico-Philosophicus.txt')

# f2 = open('Texts/NER_Results.txt','w')
# f3 = open('Texts/NER_PERSONS.txt','w')
# f4 = open('Texts/NER_Unique_PERSONS.txt','w')
# f5 = open('Texts/NER_LOCATIONS.txt','w')
# f6 = open('Texts/ALL_DISTANCE_CASES.txt','w')
# f7 = open('Texts/uniquenames.csv','w')

book=f1.read()
persons =[]

# Tagging of words with PERSON,LOCATION, ORGANISATION
# results2= st.tag(book.split())


# for name,entity in results2:
#     if entity == "PERSON":
#         if name not in persons:
#             persons.append(name)

# dictionary with frequence of names

persons1=[]
for elem in persons:
    persons1.append(elem.strip('.').strip('"').strip(','))
for k in persons1:
    if len(k) == 2:
        persons1.remove(k)
persons1.sort()

temp= list(set(persons1))
unique_persons_list = [s for s in temp if len(s) != 1]

unique_persons_list.sort()

# book.replace("Madame Charpentier","Mrs. Charpentier")
# book.replace("Madame Ferraud","Countess Ferraud")
# book.replace("M. Ferraud","Comte Ferraud")
# book.replace("Monsieur Ferraud","Comte Ferraud")

# book.replace("Mademoiselle","Mlle.")
# book.replace("Mlle. de Cominges","Mlle. Blanche")
# book.replace("Madame la General","Mdme. de Cominges")
# book.replace("Comtesse","Mdme. de Cominges")
# book.replace("Widow de Cominges","Mdme. de Cominges")




book_in_paragraphs = book.split('\n\n')



selection= input("1. sentences\n 2. paragraph\n")
if selection ==1:
    ALL_sentences=sent_tokenize(book)
else:
    ALL_sentences=book_in_paragraphs
combinations_persons = list(itertools.combinations(unique_persons_list,2))

len_list = len(combinations_persons)

couples =[]
distances= []
occurences = []
list1 = []
list2= []
for i in range(1,len_list):
    for j in ALL_sentences:
        temp= list(combinations_persons[i])

        out  = re.compile(str(temp[0])+'(.*?)'+str(temp[1]), re.DOTALL |  re.IGNORECASE).findall(j)
        if out :
#             if  len(out[0])<=2:
#                 couples.append(str(temp[0])+' '+ str(temp[1]))
#             else:
            occurences.append(str(temp[0])+' '+ str(temp[1]))

            distances.append(str(temp[0])+' '+ str(temp[1])+": distance = "+str(len(out[0])))

        out2  = re.compile(str(temp[1])+'(.*?)'+str(temp[0]), re.DOTALL |  re.IGNORECASE).findall(j)
#         f6.write( "\n Person1: "+ str(temp[1])+" to Person2: " +str(temp[0]) + "\n..............\n")
        if out2 :
#             if  len(out2[0])<=2:
#                 couples.append(str(temp[1])+' '+ str(temp[0]))
#             else:
            occurences.append(str(temp[1])+' '+ str(temp[0]))

            distances.append(str(temp[1])+' '+ str(temp[0])+": distance = "+str(len(out2[0])))

# print "--------------DISTANCES---------------"
# print distances
# print "--------------------------------------"


# temp= list(set(couples))
# unique_couples_list = [s for s in temp if len(s) != 1]
# unique_couples_list.sort()

# for k in unique_couples_list:
#     whole_name=k.split(' ')
#     temp1 = whole_name[1]+ " "+whole_name[0]
#     if  temp1 in unique_couples_list:
#         unique_couples_list.remove(temp1)
# Out:
# 1. sentences
#  2. paragraph
# 1

# %%
# print "-------------- Unique COUPLES-----------------"
# print unique_couples_list
# print "--------------------------------------"

# %%
###################################################################################   2

# for k in unique_couples_list:
#     whole_name=k.split(' ')
#     #print whole_name
#     #print whole_name[0]
#     #print whole_name[1]
#     temp =whole_name[0]+"--"+whole_name[1]
#     if whole_name[0] in unique_persons_list:
#         unique_persons_list.remove(whole_name[0])
#     if whole_name[1] in unique_persons_list:
#         unique_persons_list.remove(whole_name[1])
#     if temp in unique_persons_list:
#         unique_persons_list.remove(temp)
#     unique_persons_list.append(k)
#     book.replace(whole_name[0],k)
#     book.replace(whole_name[1],k)

# temp= list(set(unique_persons_list))
# unique_persons_list2 = [s for s in temp if len(s) != 1]
# unique_persons_list2.sort()


# print '--------- Unique  names 2------------'
# for k in unique_persons_list2:
#     print k

# print "-----------------------------------"

# %%
unique_persons_list2=[
"language","reality","science","case","fact","existence","state", "affair","picture","thought",
    "sense","proposition","logical","truth","function","world","space","being","atomic","object",
    "subject","substance","theory","entities","things","form","Plato","Aristotle","Heraclitus",
    "possibility","structure","essence","geometric","relation","shown","speak","silent",
    "representation","model","metaphysics","accident","saying"
]
#"thing",
print  len(unique_persons_list2)

unique_persons_list2.sort()
print unique_persons_list2
# Out:
# 42
# ['Aristotle', 'Heraclitus', 'Plato', 'accident', 'affair', 'atomic', 'being', 'case', 'entities', 'essence', 'existence', 'fact', 'form', 'function', 'geometric', 'language', 'logical', 'metaphysics', 'model', 'object', 'picture', 'possibility', 'proposition', 'reality', 'relation', 'representation', 'saying', 'science', 'sense', 'shown', 'silent', 'space', 'speak', 'state', 'structure', 'subject', 'substance', 'theory', 'things', 'thought', 'truth', 'world']

# %%
###################################################################################   3

if selection ==1:
    ALL_sentences=sent_tokenize(book)
else:
    ALL_sentences=book_in_paragraphs

#ALL_sentences=sent_tokenize(book)
combinations_persons = list(itertools.combinations(unique_persons_list2,2))

len_list = len(combinations_persons)

couples =[]
distances= []
occurences = []
list1 = []
list2= []
for i in range(1,len_list):
    for j in ALL_sentences:
        temp= list(combinations_persons[i])

        out  = re.compile(str(temp[0])+'(.*?)'+str(temp[1]), re.DOTALL |  re.IGNORECASE).findall(j)
        if out :
#             if  len(out[0])<=2:
#                 couples.append(str(temp[0])+' '+ str(temp[1]))
#             else:
            occurences.append(str(temp[0])+' - '+ str(temp[1]))

            distances.append(str(temp[0])+' '+ str(temp[1])+": distance = "+str(len(out[0])))


        out2  = re.compile(str(temp[1])+'(.*?)'+str(temp[0]), re.DOTALL |  re.IGNORECASE).findall(j)
#         f6.write( "\n Person1: "+ str(temp[1])+" to Person2: " +str(temp[0]) + "\n..............\n")
        if out2 :
#             if  len(out2[0])<=2:
#                 couples.append(str(temp[1])+' '+ str(temp[0]))
#             else:
            occurences.append(str(temp[1])+' - '+ str(temp[0]))

            distances.append(str(temp[1])+' '+ str(temp[0])+": distance = "+str(len(out2[0])))


#print ALL_sentences
print "--------------DISTANCES---------------"
print distances
print "--------------------------------------"

print "--------------occurences-----------------"
print occurences
print "--------------------------------------"

# temp= list(set(couples))
# unique_couples_list = [s for s in temp if len(s) != 1]
# unique_couples_list.sort()


# print "-------------- Unique COUPLES-----------------"
# print unique_couples_list
# print "--------------------------------------"


dict_occurences={}
for i in occurences:
    if i not in dict_occurences:
        dict_occurences[i] = 1
    else:
        dict_occurences[i] = dict_occurences[i]+1


print '------ Number of co-occurences of 2 names--------------'

for i in dict_occurences:
    print i, dict_occurences[i]

print "-----------------------------------"
# Out:
# --------------DISTANCES---------------
# ['accident affair: distance = 40', 'case accident: distance = 65', 'case accident: distance = 5', 'fact accident: distance = 53', 'logical accident: distance = 128', 'accident possibility: distance = 53', 'proposition accident: distance = 25', 'accident proposition: distance = 73', 'accident proposition: distance = 28', 'proposition accident: distance = 185', 'relation accident: distance = 152', 'accident state: distance = 30', 'accident things: distance = 19', 'truth accident: distance = 41', 'accident world: distance = 25', 'world accident: distance = 38', 'case affair: distance = 40', 'affair case: distance = 14', 'existence affair: distance = 14', 'existence affair: distance = 32', 'affair existence: distance = 35', 'existence affair: distance = 14', 'affair existence: distance = 33', 'existence affair: distance = 34', 'existence affair: distance = 34', 'existence affair: distance = 33', 'existence affair: distance = 33', 'existence affair: distance = 32', 'existence affair: distance = 15', 'affair existence: distance = 30', 'existence affair: distance = 32', 'fact affair: distance = 32', 'fact affair: distance = 42', 'affair fact: distance = 13', 'affair fact: distance = 22', 'fact affair: distance = 40', 'affair form: distance = 5', 'form affair: distance = 56', 'affair form: distance = 9', 'affair form: distance = 87', 'form affair: distance = 40', 'logical affair: distance = 55', 'affair object: distance = 42', 'object affair: distance = 24', 'object affair: distance = 56', 'object affair: distance = 59', 'affair object: distance = 21', 'object affair: distance = 21', 'affair object: distance = 2', 'affair object: distance = 2', 'object affair: distance = 31', 'object affair: distance = 17', 'affair object: distance = 38', 'affair object: distance = 61', 'object affair: distance = 55', 'picture affair: distance = 87', 'picture affair: distance = 92', 'affair picture: distance = 49', 'affair possibility: distance = 7', 'possibility affair: distance = 17', 'affair possibility: distance = 8', 'affair possibility: distance = 44', 'possibility affair: distance = 31', 'possibility affair: distance = 46', 'proposition affair: distance = 33', 'proposition affair: distance = 58', 'proposition affair: distance = 149', 'proposition affair: distance = 99', 'proposition affair: distance = 66', 'affair proposition: distance = 28', 'proposition affair: distance = 23', 'proposition affair: distance = 66', 'affair reality: distance = 5', 'reality affair: distance = 76', 'affair relation: distance = 33', 'affair relation: distance = 94', 'relation affair: distance = 105', 'affair sense: distance = 75', 'sense affair: distance = 63', 'sense affair: distance = 116', 'space affair: distance = 23', 'space affair: distance = 49', 'state affair: distance = 5', 'affair state: distance = 5', 'state affair: distance = 4', 'state affair: distance = 5', 'affair state: distance = 26', 'state affair: distance = 5', 'state affair: distance = 5', 'state affair: distance = 5', 'state affair: distance = 5', 'state affair: distance = 5', 'state affair: distance = 6', 'state affair: distance = 5', 'state affair: distance = 5', 'state affair: distance = 5', 'state affair: distance = 4', 'state affair: distance = 4', 'affair state: distance = 26', 'state affair: distance = 5', 'state affair: distance = 6', 'state affair: distance = 5', 'affair state: distance = 25', 'state affair: distance = 5', 'state affair: distance = 5', 'state affair: distance = 5', 'state affair: distance = 5', 'state affair: distance = 4', 'state affair: distance = 5', 'state affair: distance = 5', 'state affair: distance = 4', 'state affair: distance = 4', 'state affair: distance = 4', 'state affair: distance = 4', 'state affair: distance = 6', 'state affair: distance = 5', 'state affair: distance = 5', 'state affair: distance = 5', 'state affair: distance = 4', 'affair state: distance = 12', 'state affair: distance = 5', 'affair state: distance = 54', 'state affair: distance = 4',  ...
# --------------------------------------
# --------------occurences-----------------
# ['accident - affair', 'case - accident', 'case - accident', 'fact - accident', 'logical - accident', 'accident - possibility', 'proposition - accident', 'accident - proposition', 'accident - proposition', 'proposition - accident', 'relation - accident', 'accident - state', 'accident - things', 'truth - accident', 'accident - world', 'world - accident', 'case - affair', 'affair - case', 'existence - affair', 'existence - affair', 'affair - existence', 'existence - affair', 'affair - existence', 'existence - affair', 'existence - affair', 'existence - affair', 'existence - affair', 'existence - affair', 'existence - affair', 'affair - existence', 'existence - affair', 'fact - affair', 'fact - affair', 'affair - fact', 'affair - fact', 'fact - affair', 'affair - form', 'form - affair', 'affair - form', 'affair - form', 'form - affair', 'logical - affair', 'affair - object', 'object - affair', 'object - affair', 'object - affair', 'affair - object', 'object - affair', 'affair - object', 'affair - object', 'object - affair', 'object - affair', 'affair - object', 'affair - object', 'object - affair', 'picture - affair', 'picture - affair', 'affair - picture', 'affair - possibility', 'possibility - affair', 'affair - possibility', 'affair - possibility', 'possibility - affair', 'possibility - affair', 'proposition - affair', 'proposition - affair', 'proposition - affair', 'proposition - affair', 'proposition - affair', 'affair - proposition', 'proposition - affair', 'proposition - affair', 'affair - reality', 'reality - affair', 'affair - relation', 'affair - relation', 'relation - affair', 'affair - sense', 'sense - affair', 'sense - affair', 'space - affair', 'space - affair', 'state - affair', 'affair - state', 'state - affair', 'state - affair', 'affair - state', 'state - affair', 'state - affair', 'state - affair', 'state - affair', 'state - affair', 'state - affair', 'state - affair', 'state - affair', 'state - affair', 'state - affair', 'state - affair', 'affair - state', 'state - affair', 'state - affair', 'state - affair', 'affair - state', 'state - affair', 'state - affair', 'state - affair', 'state - affair', 'state - affair', 'state - affair', 'state - affair', 'state - affair', 'state - affair', 'state - affair', 'state - affair', 'state - affair', 'state - affair', 'state - affair', 'state - affair', 'state - affair', 'affair - state', 'state - affair', 'affair - state', 'state - affair', 'state - affair', 'state - affair', 'state - affair', 'affair - structure', 'structure - affair', 'structure - affair', 'affair - things', 'things - affair', 'things - affair', 'things - affair', 'truth - affair', 'affair - world', 'world - affair', 'being - fact', 'fact - being', 'being - fact', 'being - form', 'being - object', 'being - picture', 'possibility - being', 'possibility - being', 'proposition - being', 'being - proposition', 'proposition - being', 'proposition - being', 'being - proposition', 'proposition - being', 'proposition - being', 'being - reality', 'being - sense', 'being - sense', 'space - being', 'being - subject', 'being - subject', 'world - being', 'being - world', 'world - being', 'being - world', 'case - essence', 'case - existence', 'fact - case', 'case - fact', 'case - fact', 'case - form', 'case - form', 'form - case', 'form - case', 'case - form', 'form - case', 'case - form', 'form - case', 'form - case', 'case - function', 'function - case', 'case - function', 'function - case', 'case - language', 'case - logical', 'logical - case', 'logical - case', 'object - case', 'case - picture', 'case - possibility', 'possibility - case', 'case - proposition', 'case - proposition', 'case - proposition', 'proposition - case', 'case - proposition', 'case - proposition', 'case - proposition', 'proposition - case', 'case - proposition', 'proposition - case', 'case - proposition', 'case - proposition', 'proposition - case', 'case - proposition', 'proposition - case', 'case - relation', 'relation - case', 'relation - c ...
# --------------------------------------
# ------ Number of co-occurences of 2 names--------------
# form - case 5
# logical - science 1
# case - thought 1
# state - things 2
# thought - picture 1
# fact - case 1
# picture - possibility 3
# reality - space 1
# existence - sense 1
# space - substance 1
# things - affair 3
# fact - language 4
# things - state 3
# reality - affair 1
# space - existence 1
# things - picture 1
# picture - state 2
# thought - space 1
# affair - form 3
# model - sense 1
# sense - things 1
# affair - relation 2
# sense - affair 2
# model - space 1
# sense - possibility 1
# world - things 1
# existence - logical 1
# things - sense 1
# object - things 1
# world - form 3
# state - object 6
# world - accident 1
# possibility - sense 1
# things - form 1
# accident - affair 1
# picture - representation 1
# being - reality 1
# case - essence 1
# sense - reality 2
# fact - things 3
# fact - truth 3
# accident - possibility 1
# representation - form 2
# logical - reality 2
# sense - speak 4
# logical - space 7
# world - saying 1
# things - thought 1
# sense - existence 1
# fact - sense 4
# relation - function 1
# sense - truth 3
# theory - proposition 2
# proposition - affair 7
# form - saying 2
# world - language 2
# fact - existence 2
# picture - subject 2
# picture - truth 1
# state - sense 1
# logical - structure 1
# object - possibility 4
# substance - form 1
# affair - structure 1
# proposition - things 7
# case - relation 1
# logical - object 4
# space - being 1
# substance - proposition 1
# state - theory 1
# reality - possibility 1
# subject - sense 1
# thought - truth 2
# saying - form 1
# speak - object 3
# logical - sense 4
# thought - world 2
# fact - space 1
# world - fact 8
# space - reality 1
# reality - logical 3
# sense - subject 1
# fact - world 4
# existence - fact 2
# sense - shown 1
# language - world 4
# proposition - science 4
# object - proposition 6
# state - case 1
# state - world 1
# sense - space 1
# representation - relation 1
# picture - proposition 1
# truth - proposition 35
# state - affair 38
# things - function 1
# logical - language 2
# reality - truth 1
# fact - picture 2
# world - representation 1
# state - shown 1
# thought - speak 1
# form - possibility 2
# world - shown 1
# state - relation 2
# form - speak 1
# existence - affair 10
# state - reality 1
# fact - affair 3
# form - logical 5
# space - object 2
# picture - thought 1
# fact - thought 1
# world - reality 1
# object - space 2
# space - form 1
# language - existence 1
# essence - world 2
# truth - function 17
# object - affair 7
# possibility - affair 3
# case - function 2
# relation - sense 1
# picture - affair 2
# picture - saying 1
# proposition - form 38
# things - case 1
# proposition - saying 1
# form - essence 1
# logical - affair 1
# function - case 2
# form - existence 2
# truth - form 3
# proposition - existence 6
# sense - object 2
# sense - fact 2
# picture - object 2
# essence - function 1
# fact - state 3
# proposition - fact 12
# proposition - accident 2
# picture - geometric 1
# speak - world 2
# essence - sense 1
# possibility - case 1
# truth - object 1
# form - language 2
# object - structure 1
# proposition - object 12
# function - form 3
# form - truth 3
# proposition - function 10
# fact - logical 5
# saying - proposition 1
# language - thought 3
# object - world 3
# subject - world 2
# world - substance 1
# object - thought 2
# object - logical 3
# shown - fact 1
# space - logical 2
# world - essence 1
# possibility - form 4
# relation - proposition 8
# possibility - object 2
# proposition - possibility 2
# thought - logical 1
# reality - proposition 2
# relation - truth 1
# structure - picture 1
# model - reality 2
# case - truth 2
# object - sense 5
# saying - world 1
# substance - world 2
# object - state 7
# affair - reality 1
# form - thought 3
# truth - sense 2
# fact - object 2
# fact - accident 1
# truth - structure 1
# theory - form 1
# theory - science 1
# proposition - relation 9
# language - proposition 4
# fact - function 2
# function - things 1
# sense - relation 2
# case - proposition 10
# picture - things 1
# truth - world 2
# form - world 4
# picture - space 3
# fact - essence 1
# form - relation 4
# affair - existence 3
# proposition - substance 1
# sense - logical 4
# object - fact 2
# thought - possibility 2
# form - object 7
# function - logical 2
# state - picture 2
# proposition - reality 10
# affair - sense 1
# language - relation 1
# sense - state 3
# reality - existence 1
# relation - picture 2
# function - relation 1
# sense - form 4
# possibility - state 3
# being - subject 2
# case - existence 1
# affair - picture 1
# relation - accident 1
# state - possibility 3
# logical - accident 1
# form - fact 5
# picture - reality 14
# truth - logical 4
# sense - function 1
# logical - state 2
# affair - case 1
# structure - state 2
# thought - proposition 3
# space - affair 2
# structure - relation 1
# things - object 1
# reality - object 1
# structure - affair 2
# proposition - state 12
# relation - structure 1
# substance - case 1
# form - state 2
# proposition - logical 24
# relation - object 4
# space - world 1
# world - logical 1
# thought - fact 1
# relation - existence 1
# affair - object 6
# form - sense 7
# case - picture 1
# proposition - space 4
# geometric - form 1
# thought - object 2
# affair - proposition 1
# proposition - essence 2
# proposition - model 2
# logical - thought 3
# object - picture 1
# state - existence 3
# world - affair 1
# logical - fact 4
# accident - proposition 2
# relation - fact 1
# object - substance 1
# thought - form 2
# logical - saying 1
# world - case 2
# proposition - sense 41
# things - relation 1
# object - reality 1
# proposition - truth 32
# world - sense 2
# language - speak 1
# case - affair 1
# fact - structure 2
# theory - function 1
# existence - reality 1
# world - object 2
# relation - state 1
# relation - case 4
# truth - saying 1
# state - structure 1
# object - relation 5
# language - possibility 1
# case - fact 2
# substance - sense 1
# structure - form 1
# picture - form 11
# picture - logical 5
# speak - logical 1
# logical - existence 3
# proposition - shown 2
# case - accident 2
# being - proposition 2
# reality - world 1
# speak - proposition 1
# language - truth 1
# saying - sense 1
# logical - proposition 32
# logical - case 2
# picture - model 2
# logical - things 1
# proposition - thought 6
# case - possibility 1
# speak - sense 1
# logical - truth 2
# form - affair 2
# thought - relation 2
# fact - relation 4
# function - sense 1
# affair - state 6
# world - proposition 9
# world - being 2
# picture - structure 1
# accident - state 1
# truth - thought 2
# space - possibility 1
# fact - proposition 12
# being - sense 2
# structure - proposition 2
# things - possibility 1
# truth - state 1
# relation - affair 1
# affair - world 1
# case - language 1
# truth - affair 1
# sense - substance 1
# logical - form 19
# truth - existence 2
# speak - space 1
# reality - state 1
# picture - sense 3
# being - object 1
# space - state 2
# possibility - existence 1
# affair - possibility 3
# affair - things 1
# state - proposition 4
# possibility - essence 1
# truth - fact 2
# being - fact 2
# relation - reality 2
# relation - language 2
# form - reality 3
# proposition - world 13
# possibility - things 1
# relation - representation 1
# existence - state 10
# existence - relation 1
# proposition - being 5
# sense - case 3
# structure - possibility 1
# being - world 2
# case - state 1
# case - sense 3
# object - case 1
# proposition - theory 1
# proposition - language 5
# sense - world 3
# logical - possibility 2
# proposition - structure 2
# world - relation 1
# relation - things 1
# state - fact 2
# representation - reality 1
# proposition - case 5
# possibility - logical 3
# possibility - being 2
# form - science 1
# form - function 4
# things - proposition 1
# fact - form 9
# relation - form 3
# sense - proposition 17
# fact - being 1
# world - state 1
# form - representation 1
# existence - language 1
# possibility - structure 2
# language - sense 5
# function - truth 5
# proposition - picture 9
# form - proposition 29
# case - things 1
# language - form 1
# form - picture 5
# world - subject 2
# picture - existence 2
# truth - case 1
# essence - truth 1
# truth - relation 1
# things - world 2
# existence - form 1
# state - logical 1
# function - proposition 11
# picture - substance 1
# picture - fact 3
# existence - speak 1
# affair - fact 2
# essence - object 1
# being - picture 1
# essence - proposition 5
# form - structure 1
# speak - form 1
# state - form 3
# case - form 4
# relation - world 3
# possibility - world 2
# possibility - picture 3
# subject - proposition 1
# picture - world 3
# possibility - thought 2
# case - logical 1
# logical - world 7
# possibility - fact 2
# picture - relation 1
# possibility - proposition 3
# being - form 1
# shown - proposition 1
# model - substance 1
# logical - speak 1
# structure - fact 1
# truth - accident 1
# language - space 1
# thought - sense 2
# speak - subject 1
# case - world 3
# object - form 5
# speak - things 1
# form - things 2
# accident - things 1
# possibility - truth 1
# language - logical 4
# accident - world 1
# reality - form 4
# shown - object 1
# fact - speak 1
# logical - picture 6
# language - picture 1
# existence - proposition 6
# -----------------------------------

# %%
# %matplotlib inline 
# %load_ext autoreload
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import pickle

# %%
# %autoreload 2
from utils import *
G=nx.Graph()

for eds,wei in dict_occurences.items():
#     print ed,wei
    ed=eds.split(' - ')
    
    G.add_edge(ed[0],ed[1],weight=wei)
    G.add_node(ed[0],label=ed[0])
    G.add_node(ed[1],label=ed[1])
# print G.nodes(data=True)


pos=nx.spring_layout(G,scale=50,k=0.5,iterations=70)
sstt="Ludwig Wittgenstein's Tractatus Logico-Philosophicus"
posit=draw_network(G,sstt,pos=pos,with_edgewidth=True,withLabels=True,labfs=18,valpha=0.1,ealpha=0.4,labelfont=15)

# %%
draw_centralities_subplots(G,pos,withLabels=False,labfs=5,figsi=(15,22),ealpha=0.4)

# %%
from chAs import draw_comms,modul_arity
import community as comm

part=comm.best_partition(G) 
print 'Number of communities of %s = %i' %(sstt, max(part.values())+1)
print 'Community partition of %s:' %(sstt)
parLis=[]
partdi={}
for i,k in part.items():
    if k not in partdi:
        partdi[k]=[i]
    else:
        partdi[k].append(i)
for i,k in partdi.items():
    parLis.append(k)
print parLis
nodper={i:i for i in G.nodes()}
print 'Community modularity of %s = %.4f' %(sstt, comm.modularity(part,G))

d=0.8 
dd=0.8
c=1.2
cc=1.4
alpha=0.2
ealpha=.2
vcc={}
sstta="The %s %s Communities" %(max(part.values())+1,sstt)

draw_comms(G,G.nodes(),[],[],[] ,part,part,d,dd,c,cc,alpha,ealpha,nodper,sstta,titlefont=20,labelfont=15,valpha=0.5)
# Out:
# Number of communities of Ludwig Wittgenstein's Tractatus Logico-Philosophicus = 4
# Community partition of Ludwig Wittgenstein's Tractatus Logico-Philosophicus:
# [['affair', 'existence', 'speak', 'shown', 'space', 'state', 'object', 'possibility', 'structure'], ['saying', 'essence', 'logical', 'proposition', 'function', 'theory', 'form', 'science', 'truth'], ['being', 'relation', 'sense', 'things', 'subject', 'accident', 'world', 'case', 'substance', 'language', 'thought', 'fact'], ['reality', 'geometric', 'picture', 'representation', 'model']]
# Community modularity of Ludwig Wittgenstein's Tractatus Logico-Philosophicus = 0.1415
