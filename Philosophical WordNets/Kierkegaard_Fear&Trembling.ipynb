# %% [markdown]
# # PHILOSOPHY NETWORKS:
# ## Extraction of Sentence-Co-Occurring Relationships among Concepts
# # Søren Kierkegaard's Fear and Trembling

# %%
import nltk

# %%
import os
import re
import csv
import itertools
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.tag.stanford import StanfordNERTagger
# java_path = "C:/Program Files/Java/jdk1.8.0_05/bin/java.exe"
# os.environ['JAVAHOME'] = java_path

# path2 = 'C:/Users/Pantelis/Desktop/NOTEBOOK/stanfordner'
# st =  StanfordNERTagger(path2+'/classifiers/english.all.3class.distsim.crf.ser.gz', 'stanford-ner.jar')

# st =  StanfordNERTagger('/Users/mosesboudourides/Dropbox/Python Projects/LiteratureNetworks/stanfordner/classifiers/english.all.3class.distsim.crf.ser.gz', '/Users/mosesboudourides/Dropbox/Python Projects/LiteratureNetworks/stanfordner/stanford-ner.jar')
# st = StanfordNERTagger('classifiers/english.all.3class.distsim.crf.ser.gz','/home/sergios-len/Downloads/stanford-ner-2015-12-09/stanford-ner.jar')


# f1 = open('Texts/Kierkegaard_Fear&Trembling.txt','r')

import codecs
f1 = codecs.open('Texts/Kierkegaard_Fear&Trembling.txt', "r", encoding="utf-8")
f1Temp = codecs.open("tempASCII", "w", encoding="ascii", errors="ignore")
f1Temp.write('Texts/Kierkegaard_Fear&Trembling.txt')

# f2 = open('Texts/NER_Results.txt','w')
# f3 = open('Texts/NER_PERSONS.txt','w')
# f4 = open('Texts/NER_Unique_PERSONS.txt','w')
# f5 = open('Texts/NER_LOCATIONS.txt','w')
# f6 = open('Texts/ALL_DISTANCE_CASES.txt','w')
# f7 = open('Texts/uniquenames.csv','w')

book=f1.read()
persons =[]

# Tagging of words with PERSON,LOCATION, ORGANISATION
# results2= st.tag(book.split())


# for name,entity in results2:
#     if entity == "PERSON":
#         if name not in persons:
#             persons.append(name)

# dictionary with frequence of names

persons1=[]
for elem in persons:
    persons1.append(elem.strip('.').strip('"').strip(','))
for k in persons1:
    if len(k) == 2:
        persons1.remove(k)
persons1.sort()

temp= list(set(persons1))
unique_persons_list = [s for s in temp if len(s) != 1]

unique_persons_list.sort()

# book.replace("Comtesse","Countess")
# book.replace("Madame Ferraud","Countess Ferraud")
# book.replace("M. Ferraud","Comte Ferraud")
# book.replace("Monsieur Ferraud","Comte Ferraud")

# book.replace("Mademoiselle","Mlle.")
# book.replace("Mlle. de Cominges","Mlle. Blanche")
# book.replace("Madame la General","Mdme. de Cominges")
# book.replace("Comtesse","Mdme. de Cominges")
# book.replace("Widow de Cominges","Mdme. de Cominges")




book_in_paragraphs = book.split('\n\n')



selection= input("1. sentences\n 2. paragraph\n")
if selection ==1:
    ALL_sentences=sent_tokenize(book)
else:
    ALL_sentences=book_in_paragraphs
combinations_persons = list(itertools.combinations(unique_persons_list,2))

len_list = len(combinations_persons)

couples =[]
distances= []
occurences = []
list1 = []
list2= []
for i in range(1,len_list):
    for j in ALL_sentences:
        temp= list(combinations_persons[i])

        out  = re.compile(str(temp[0])+'(.*?)'+str(temp[1]), re.DOTALL |  re.IGNORECASE).findall(j)
        if out :
#             if  len(out[0])<=2:
#                 couples.append(str(temp[0])+' '+ str(temp[1]))
#             else:
            occurences.append(str(temp[0])+' '+ str(temp[1]))

            distances.append(str(temp[0])+' '+ str(temp[1])+": distance = "+str(len(out[0])))

        out2  = re.compile(str(temp[1])+'(.*?)'+str(temp[0]), re.DOTALL |  re.IGNORECASE).findall(j)
#         f6.write( "\n Person1: "+ str(temp[1])+" to Person2: " +str(temp[0]) + "\n..............\n")
        if out2 :
#             if  len(out2[0])<=2:
#                 couples.append(str(temp[1])+' '+ str(temp[0]))
#             else:
            occurences.append(str(temp[1])+' '+ str(temp[0]))

            distances.append(str(temp[1])+' '+ str(temp[0])+": distance = "+str(len(out2[0])))

# print "--------------DISTANCES---------------"
# print distances
# print "--------------------------------------"


# temp= list(set(couples))
# unique_couples_list = [s for s in temp if len(s) != 1]
# unique_couples_list.sort()

# for k in unique_couples_list:
#     whole_name=k.split(' ')
#     temp1 = whole_name[1]+ " "+whole_name[0]
#     if  temp1 in unique_couples_list:
#         unique_couples_list.remove(temp1)
# Out:
# 1. sentences
#  2. paragraph
# 1

# %%
# print "-------------- Unique COUPLES-----------------"
# print unique_couples_list
# print "--------------------------------------"

# %%
###################################################################################   2

# for k in unique_couples_list:
#     whole_name=k.split(' ')
#     #print whole_name
#     #print whole_name[0]
#     #print whole_name[1]
#     temp =whole_name[0]+"--"+whole_name[1]
#     if whole_name[0] in unique_persons_list:
#         unique_persons_list.remove(whole_name[0])
#     if whole_name[1] in unique_persons_list:
#         unique_persons_list.remove(whole_name[1])
#     if temp in unique_persons_list:
#         unique_persons_list.remove(temp)
#     unique_persons_list.append(k)
#     book.replace(whole_name[0],k)
#     book.replace(whole_name[1],k)

# temp= list(set(unique_persons_list))
# unique_persons_list2 = [s for s in temp if len(s) != 1]
# unique_persons_list2.sort()


# print '--------- Unique  names 2------------'
# for k in unique_persons_list2:
#     print k

# print "-----------------------------------"

# %%
unique_persons_list2=[
"Abraham","Isaac","God","Sarah","son","individual","child","tempt","faith","story","virtue",
    "love","eternal","fear","expect","world","expression","existence","ethical","duty",
    "absolute","life","right","reason","speak","act","rest","mad","happy","demon","soul",
    "good","Hegel","murder","thought","relation","spirit","nature","philosophy","resign","gain",
    "leap","paradox","Agamemnon","sense","person","being","secret","sacrifice","tragic",
    "strength","joy","task","Agnes","merman","Moriah"
]
#"thing",
print  len(unique_persons_list2)

unique_persons_list2.sort()
print unique_persons_list2
# Out:
# 56
# ['Abraham', 'Agamemnon', 'Agnes', 'God', 'Hegel', 'Isaac', 'Moriah', 'Sarah', 'absolute', 'act', 'being', 'child', 'demon', 'duty', 'eternal', 'ethical', 'existence', 'expect', 'expression', 'faith', 'fear', 'gain', 'good', 'happy', 'individual', 'joy', 'leap', 'life', 'love', 'mad', 'merman', 'murder', 'nature', 'paradox', 'person', 'philosophy', 'reason', 'relation', 'resign', 'rest', 'right', 'sacrifice', 'secret', 'sense', 'son', 'soul', 'speak', 'spirit', 'story', 'strength', 'task', 'tempt', 'thought', 'tragic', 'virtue', 'world']

# %%
###################################################################################   3

if selection ==1:
    ALL_sentences=sent_tokenize(book)
else:
    ALL_sentences=book_in_paragraphs

#ALL_sentences=sent_tokenize(book)
combinations_persons = list(itertools.combinations(unique_persons_list2,2))

len_list = len(combinations_persons)

couples =[]
distances= []
occurences = []
list1 = []
list2= []
for i in range(1,len_list):
    for j in ALL_sentences:
        temp= list(combinations_persons[i])

        out  = re.compile(str(temp[0])+'(.*?)'+str(temp[1]), re.DOTALL |  re.IGNORECASE).findall(j)
        if out :
#             if  len(out[0])<=2:
#                 couples.append(str(temp[0])+' '+ str(temp[1]))
#             else:
            occurences.append(str(temp[0])+' - '+ str(temp[1]))

            distances.append(str(temp[0])+' '+ str(temp[1])+": distance = "+str(len(out[0])))


        out2  = re.compile(str(temp[1])+'(.*?)'+str(temp[0]), re.DOTALL |  re.IGNORECASE).findall(j)
#         f6.write( "\n Person1: "+ str(temp[1])+" to Person2: " +str(temp[0]) + "\n..............\n")
        if out2 :
#             if  len(out2[0])<=2:
#                 couples.append(str(temp[1])+' '+ str(temp[0]))
#             else:
            occurences.append(str(temp[1])+' - '+ str(temp[0]))

            distances.append(str(temp[1])+' '+ str(temp[0])+": distance = "+str(len(out2[0])))


#print ALL_sentences
print "--------------DISTANCES---------------"
print distances
print "--------------------------------------"

print "--------------occurences-----------------"
print occurences
print "--------------------------------------"

# temp= list(set(couples))
# unique_couples_list = [s for s in temp if len(s) != 1]
# unique_couples_list.sort()


# print "-------------- Unique COUPLES-----------------"
# print unique_couples_list
# print "--------------------------------------"


dict_occurences={}
for i in occurences:
    if i not in dict_occurences:
        dict_occurences[i] = 1
    else:
        dict_occurences[i] = dict_occurences[i]+1


print '------ Number of co-occurences of 2 names--------------'

for i in dict_occurences:
    print i, dict_occurences[i]

print "-----------------------------------"
# Out:
# --------------DISTANCES---------------
# ['God Abraham: distance = 9', 'God Abraham: distance = 159', 'God Abraham: distance = 9', 'God Abraham: distance = 4', 'Abraham God: distance = 38', 'Abraham God: distance = 88', 'Abraham God: distance = 70', 'God Abraham: distance = 9', 'Abraham God: distance = 5', 'God Abraham: distance = 11', 'God Abraham: distance = 9', 'Abraham God: distance = 154', 'Abraham God: distance = 26', 'God Abraham: distance = 13', 'Abraham God: distance = 35', 'Abraham God: distance = 226', 'God Abraham: distance = 38', 'Abraham God: distance = 163', 'God Abraham: distance = 37', 'God Abraham: distance = 269', 'Abraham God: distance = 102', 'Abraham God: distance = 7', 'Abraham God: distance = 130', 'Hegel Abraham: distance = 20', 'Hegel Abraham: distance = 35', 'Hegel Abraham: distance = 96', 'Hegel Abraham: distance = 69', 'Isaac Abraham: distance = 28', 'Abraham Isaac: distance = 38', 'Abraham Isaac: distance = 113', 'Abraham Isaac: distance = 25', 'Abraham Isaac: distance = 61', 'Abraham Isaac: distance = 43', 'Isaac Abraham: distance = 74', 'Isaac Abraham: distance = 11', 'Abraham Isaac: distance = 78', 'Isaac Abraham: distance = 23', 'Abraham Isaac: distance = 68', 'Abraham Isaac: distance = 150', 'Abraham Isaac: distance = 5', 'Abraham Isaac: distance = 99', 'Isaac Abraham: distance = 91', 'Isaac Abraham: distance = 52', 'Abraham Isaac: distance = 25', 'Abraham Isaac: distance = 38', 'Isaac Abraham: distance = 15', 'Abraham Isaac: distance = 231', 'Abraham Isaac: distance = 144', 'Isaac Abraham: distance = 9', 'Isaac Abraham: distance = 41', 'Abraham Isaac: distance = 67', 'Abraham Isaac: distance = 199', 'Abraham Isaac: distance = 30', 'Isaac Abraham: distance = 162', 'Abraham Isaac: distance = 18', 'Abraham Isaac: distance = 7', 'Abraham Isaac: distance = 33', 'Isaac Abraham: distance = 4', 'Abraham Isaac: distance = 72', 'Abraham Isaac: distance = 83', 'Isaac Abraham: distance = 130', 'Abraham Isaac: distance = 33', 'Abraham Isaac: distance = 149', 'Abraham Isaac: distance = 253', 'Isaac Abraham: distance = 9', 'Abraham Isaac: distance = 15', 'Abraham Isaac: distance = 116', 'Abraham Isaac: distance = 25', 'Isaac Abraham: distance = 62', 'Abraham Isaac: distance = 66', 'Abraham Isaac: distance = 121', 'Abraham Isaac: distance = 302', 'Abraham Isaac: distance = 66', 'Isaac Abraham: distance = 68', 'Abraham Isaac: distance = 86', 'Abraham Isaac: distance = 80', 'Isaac Abraham: distance = 6', 'Abraham Isaac: distance = 35', 'Isaac Abraham: distance = 14', 'Abraham Isaac: distance = 35', 'Abraham Isaac: distance = 43', 'Abraham Isaac: distance = 10', 'Isaac Abraham: distance = 160', 'Abraham Isaac: distance = 108', 'Abraham Moriah: distance = 34', 'Abraham Moriah: distance = 96', 'Abraham Moriah: distance = 60', 'Abraham Moriah: distance = 107', 'Abraham Moriah: distance = 122', 'Abraham Moriah: distance = 38', 'Abraham Moriah: distance = 37', 'Moriah Abraham: distance = 84', 'Abraham Moriah: distance = 96', 'Abraham Moriah: distance = 147', 'Abraham Moriah: distance = 26', 'Abraham Moriah: distance = 48', 'Moriah Abraham: distance = 147', 'Abraham Moriah: distance = 126', 'Abraham Moriah: distance = 180', 'Moriah Abraham: distance = 32', 'Moriah Abraham: distance = 54', 'Abraham Moriah: distance = 29', 'Moriah Abraham: distance = 140', 'Abraham Sarah: distance = 81', 'Abraham Sarah: distance = 28', 'Abraham Sarah: distance = 26', 'Abraham Sarah: distance = 13', 'Abraham Sarah: distance = 19', 'Sarah Abraham: distance = 44', 'Sarah Abraham: distance = 87', 'Abraham Sarah: distance = 5', 'Abraham Sarah: distance = 15', 'Abraham Sarah: distance = 26', 'Abraham Sarah: distance = 290', 'Abraham Sarah: distance = 15', 'Abraham Sarah: distance = 272', 'Abraham Sarah: distance = 36', 'Sarah Abraham: distance = 98', 'absolute Abraham: distance = 285', 'absolute Abraham: distance = 71', 'Abraham absolute: distance = 345', 'absolute Abraham: distance = 29', 'act Abraham: distance = 119', 'Abraham act: distance = 19', 'act Abraham: distance = 86', ' ...
# --------------------------------------
# --------------occurences-----------------
# sense - rest 2
# sense - thought 2
# Agnes - person 2
# speak - tempt 2
# strength - virtue 1
# relation - tragic 2
# relation - mad 2
# Moriah - Isaac 8
# mad - love 5
# joy - murder 1
# paradox - act 6
# God - person 1
# life - tempt 1
# existence - joy 1
# mad - life 1
# speak - faith 1
# existence - resign 2
# nature - demon 2
# sense - son 3
# resign - eternal 3
# -----------------------------------

# %%
# %matplotlib inline 
# %load_ext autoreload
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import pickle

# %%
# %autoreload 2
from utils import *
G=nx.Graph()

for eds,wei in dict_occurences.items():
#     print ed,wei
    ed=eds.split(' - ')
    
    G.add_edge(ed[0],ed[1],weight=wei)
    G.add_node(ed[0],label=ed[0])
    G.add_node(ed[1],label=ed[1])
# print G.nodes(data=True)


pos=nx.spring_layout(G,scale=50,k=0.45,iterations=20)
sstt="Soren Kierkegaard's Fear and Trembling"
posit=draw_network(G,sstt,pos=pos,with_edgewidth=True,withLabels=True,labfs=18,valpha=0.1,ealpha=0.1,labelfont=15)
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/collections.py:608: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors_original != 'face':
# /usr/lib/pymodules/python2.7/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':

# %%
draw_centralities_subplots(G,pos,withLabels=False,labfs=5,figsi=(15,22))
# Out:
# /home/sergios-len/.local/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2645: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   VisibleDeprecationWarning)

# %%
from chAs import draw_comms,modul_arity
import community as comm

part=comm.best_partition(G) 
print 'Number of communities of %s = %i' %(sstt, max(part.values())+1)
print 'Community partition of %s:' %(sstt)
parLis=[]
partdi={}
for i,k in part.items():
    if k not in partdi:
        partdi[k]=[i]
    else:
        partdi[k].append(i)
for i,k in partdi.items():
    parLis.append(k)
print parLis
nodper={i:i for i in G.nodes()}
print 'Community modularity of %s = %.4f' %(sstt, comm.modularity(part,G))

d=0.8 
dd=0.8
c=1.2
cc=1.4
alpha=0.2
ealpha=.2
vcc={}
sstta="The %s %s Communities" %(max(part.values())+1,sstt)

draw_comms(G,G.nodes(),[],[],[] ,part,part,d,dd,c,cc,alpha,ealpha,nodper,sstta,titlefont=20,labelfont=15)
# Out:
# Number of communities of Soren Kierkegaard's Fear and Trembling = 5
# Community partition of Soren Kierkegaard's Fear and Trembling:
# [['Sarah', 'ethical', 'love', 'God', 'relation', 'absolute', 'story', 'duty', 'expression'], ['right', 'being', 'rest', 'expect', 'existence', 'fear', 'strength', 'leap', 'life', 'virtue', 'joy', 'philosophy', 'eternal', 'resign', 'mad', 'Hegel', 'world', 'spirit', 'task', 'Agamemnon', 'soul', 'thought', 'good', 'gain'], ['tempt', 'Moriah', 'son', 'Isaac', 'tragic', 'murder', 'sacrifice', 'reason', 'Abraham'], ['demon', 'sense', 'secret', 'speak', 'happy', 'child', 'merman', 'Agnes', 'person'], ['individual', 'paradox', 'nature', 'faith', 'act']]
# Community modularity of Soren Kierkegaard's Fear and Trembling = 0.1274
